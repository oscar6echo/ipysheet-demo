# %%
# %load_ext autoreload
# %autoreload 2

# %%
from blackscholes import BlackScholesCalculator
# Out:
# <script>
# require(["https://cdnjs.cloudflare.com/ajax/libs/vis/4.7.0/vis.js"], function(lib) {
#     console.log("The following js libs loaded:");
#     console.log("https://cdnjs.cloudflare.com/ajax/libs/vis/4.7.0/vis.js");
#     window.vis = jQuery.extend(true, {}, lib);
#     console.log('vis js lib accessible as vis');
#
# });
# </script>

# %%
bs = BlackScholesCalculator()
bs

# %%
status = bs.box.children[0].children[0].children[1].children[1].value
print(status)

if status.startswith('Last'):
    display(bs.df_pricing_one)

    print('Nb prices = ', len(bs.df_pricing_batch))
    display(bs.df_pricing_batch.head(5))
# Out:
# Last Price: 22 Jan 22:36:43
#     spot  strike  mat   vol  rate    div        d1      N_d1  N_prime_d1  \
# 0  100.0   100.0  3.0  0.15  0.02  0.005  0.303109  0.619097     0.38103
#
#          d2    ...         delta     gamma       vega     theta         rho  \
# 0  0.043301    ...      0.609879  0.014448  65.013848 -2.294698  146.143767
#
#        voma        PV       PV_K  payoff  PV_payoff
# 0  5.688712  0.941765  94.176453       0        0.0
#
# [1 rows x 23 columns]
# Nb prices =  400
#     spot  strike     mat   vol      rate    div        d1      N_d1  \
# 0  100.0   100.0  0.0001  0.15 -0.020000  0.005 -0.000917  0.499634
# 1  100.0   100.0  0.0001  0.15 -0.013684  0.005 -0.000496  0.499802
# 2  100.0   100.0  0.0001  0.15 -0.007368  0.005 -0.000075  0.499970
# 3  100.0   100.0  0.0001  0.15 -0.001053  0.005  0.000346  0.500138
# 4  100.0   100.0  0.0001  0.15  0.005263  0.005  0.000768  0.500306
#
# ...
